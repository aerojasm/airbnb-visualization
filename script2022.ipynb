# %% [markdown]
# # NYC Airbnb 2022 Listings
# ### Data Exploration

# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
first_import = pd.read_csv(pwd + "/listings_2022.csv")
first_import
# Out:
# /Users/andresrojas/opt/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 38180  54146364   Hermoso apartamento en el centro de williamsburg  230403448
# 38181  54148518                   Time Square New York -Share Room  436339796
# ...

# %%
listings_modified = first_import.drop(columns=["license", "last_review"])
listings_modified
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 38180  54146364   Hermoso apartamento en el centro de williamsburg  230403448
# 38181  54148518                   Time Square New York -Share Room  436339796
# 38182  54150715  Private PATIO in PRIVATE Room | 5mins to Manha...  340322917
# 38183  54152478      Center of Columbia University in UWS New York  438705539
# 38184  54161645  Escape to Haven in Manhattan-West 57th Street-...  355450429
#
# ...

# %%
listings_modified.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# dtype: object

# %%
print(list(listings_modified["neighbourhood_group"].unique()))
print(list(listings_modified["neighbourhood"].unique()))
print(list(listings_modified["room_type"].unique()))
print(list(listings_modified["number_of_reviews_ltm"].unique()))
# Out:
# ['Manhattan', 'Brooklyn', 'Queens', 'Staten Island', 'Bronx']
# ...

# %%
# 31224224
listings_modified[listings_modified["id"] == 31224224]
# Pandas corrects rows where the data is split in more than one row
# Out:
#              id                                               name    host_id  \
# 18857  31224224  Cozy private room with apartment to share.\n\n...  162933359
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 18857     Marie           Manhattan        Harlem  40.82283  -73.93812
#
#           room_type  price  minimum_nights  number_of_reviews  \
# 18857  Private room     50               1                 41
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 18857               1.15                               1                72
#
#        number_of_reviews_ltm
# 18857                     17

# %%
output = listings_modified.to_excel("cleaned_listings_2022.xlsx", index=False)

# %% [markdown]
# ## Conclusions
# * There are not major changes to make
# * Pandas automatically corrects rows where the data is wrongly split into more than one row
# * There are not duplicates in the categories' columns (e.g.: neighbourhood, room type)
# * Columns that will not have any use were dropped
# * This dataset is ready to use in Tableau
